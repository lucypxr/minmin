# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Xiaoran Peng**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it helps solve problems using tools and data, which makes better strategy for the companies, and make the result more persuasive.*

# %% [markdown]
# ### I want to give a value to x, and then calculate x+100

# %%
x=5
x+100
# Out:
# 105

# %% [markdown]
# ### Why I love Tableau so much:
#
# * Very easy to use, simply drag
# - Different kinds of graphs, e.g. tree, map, so that can be used in different situations
# + Really good visualization tool, the the audience comfortable listening to your stories
#
# ![alt text](http://cdn.mediajobs.com/wp-content/uploads/2017/04/Why-You-Want-to-Work-at-Tableau-%E2%80%93-They-Help-People-Actually-Understand-Their-Data.jpg "Logo Title Text 1")
#
# [Wanna know more about Tableau? Here is the link for Tableau Official Website](https://www.tableau.com/)
